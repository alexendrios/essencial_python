# %% [markdown]
# <font color="blue" size=30><b><h1>Seaborn</h1></b></font>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
dados = sns.load_dataset('tips')

# %%
dados.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.distplot(dados['total_bill'])

# %%
sns.distplot(dados['total_bill'], bins=30)

# %%
sns.jointplot(x='total_bill', y='tip', data=dados)

# %%
sns.jointplot(x='total_bill', y='tip', data=dados, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=dados, kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip', data=dados, kind='kde')

# %%
sns.pairplot(dados)

# %%
sns.pairplot(dados, hue='sex')

# %%
sns.rugplot(dados['total_bill'])

# %%
sns.rugplot(dados['tip'])

# %% [markdown]
# **Gráfico para Coluna Tipo Categórico**

# %%
sns.barplot(x='sex', y='total_bill', data=dados)

# %%
sns.countplot(x='sex', data=dados)

# %%
sns.countplot(x='smoker', data=dados)

# %%
sns.boxplot(x='day', y='total_bill', data=dados)

# %%
sns.boxplot(x='day', y='total_bill', data=dados, hue='smoker')

# %%
sns.violinplot(x='day', y='total_bill', data=dados)

# %%
sns.violinplot(x='day', y='total_bill', data=dados, hue='smoker', split=True)

# %%
sns.stripplot(x='day', y='total_bill', data=dados)

# %%
sns.stripplot(x='day', y='total_bill', data=dados, hue='sex')

# %%
sns.swarmplot(x='day', y='total_bill', data=dados, hue='sex')

# %%
sns.swarmplot(x='day', y='total_bill', data=dados, hue='sex')

# %%
sns.violinplot(x='day', y='total_bill', data=dados)
sns.swarmplot(x='day', y='total_bill', data=dados)

# %% [markdown]
# **Mapa de Calor**

# %%
valores = sns.load_dataset('flights')

# %%
valores.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
valores_matriz = valores.pivot_table(index='month', columns='year', values='passengers')
valores_matriz
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(valores_matriz)

# %%
sns.heatmap(valores_matriz, cmap='plasma')

# %%
sns.heatmap(valores_matriz, cmap='magma')

# %%
sns.heatmap(valores_matriz, cmap='inferno')

# %%
sns.heatmap(valores_matriz, cmap='viridis')

# %%
sns.heatmap(valores_matriz, cmap='coolwarm')

# %%
sns.heatmap(valores_matriz, cmap='coolwarm', linecolor='white', linewidths=2)

# %% [markdown]
# **Gráfico de Grids**

# %%
import matplotlib.pyplot as plt

# %%
flores = sns.load_dataset('iris')
flores.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(flores)

# %%
graficos = sns.PairGrid(flores)

# %%
graficos = sns.PairGrid(flores)
graficos.map(plt.scatter)

# %%
graficos = sns.PairGrid(flores)
graficos.map_diag(sns.distplot)

# %%
graficos = sns.PairGrid(flores)
graficos.map_diag(sns.distplot)
graficos.map_upper(plt.scatter)

# %%
graficos = sns.PairGrid(flores)
graficos.map_diag(sns.distplot)
graficos.map_upper(plt.scatter)
graficos.map_lower(sns.kdeplot)

# %% [markdown]
# **Face Grid**

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['time'].unique()
# Out:
# [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
df['sex'].unique()
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
df['smoker'].unique()
# Out:
# [No, Yes]
# Categories (2, object): [No, Yes]

# %%
df['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
grafico2 = sns.FacetGrid(data=df, col='sex', row='smoker')
grafico2.map(sns.distplot, 'total_bill')

# %%
grafico2 = sns.FacetGrid(data=df, col='sex', row='smoker')
grafico2.map(sns.scatterplot, 'total_bill', 'tip')

# %% [markdown]
# <font color='red'><b><h1>Gráfico de Regressão</h1></b></font>

# %%
sns.lmplot(x='total_bill', y='tip', data=df)

# %%
sns.lmplot(x='total_bill', y='tip', data=df, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=df, hue='sex', markers=['o', 'x'])

# %%
sns.lmplot(x='total_bill', y='tip', data=df, hue='sex', markers=['o', 'v'])

# %%
sns.lmplot(x='total_bill', y='tip', data=df, hue='sex', markers=['o', 'v'], scatter_kws={'s':60})

# %%
sns.lmplot(x='total_bill', y='tip', data=df, col='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=df, col='day')

# %%
sns.lmplot(x='total_bill', y='tip', data=df, col='day', row='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=df, col='day', hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=df, col='day', hue='smoker')

# %%
sns.lmplot(x='total_bill', y='tip', data=df, aspect=0.8, size=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Estilo de Cores**

# %%
sns.countplot(x='sex', data=df)

# %%
sns.set_style('darkgrid')
sns.countplot(x='sex', data=df)

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex', data=df)
sns.despine()

# %%
sns.set_style('white')
sns.countplot(x='sex', data=df)
sns.despine(left=True, bottom=True)

# %%
plt.figure(figsize=(8,4))
sns.set_style('white')
sns.countplot(x='sex', data=df)
sns.despine(left=True, bottom=True)

# %%
sns.set_context('notebook',font_scale=1.5)
plt.figure(figsize=(8,4))
sns.set_style('white')
sns.countplot(x='sex', data=df)
sns.despine(left=True, bottom=True)

# %%
sns.countplot(x='sex', data=df, palette='Set2')
